# %% [markdown]
# #  TP01 \- Deepnote Talavera Stella

# %% [markdown]
# Mi nombre es Stella

# %% [markdown]
# realizo tareas de perfil funcional

# %% [markdown]
# mi uso de la IA es muy bàsico la uso principalmente para realizar

# %% [markdown]
# consultas simples, pero estoy recien iniciando, las veces que realice las consultas lo hice a travès de chatgpt\.

# %% [markdown]
# Mi objetivo con respecto a la materia  es poder aprender\.

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=53912986-7871-4c95-9439-5a8cd34cc9f8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
